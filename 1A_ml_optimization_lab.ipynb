# %% [markdown]
# <a href="https://colab.research.google.com/github/FurqanAlyy/AI-ML-NIAI/blob/main/1A_ml_optimization_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 ML Optimization Lab (Autograded)
#
# This lab covers:
# - Gradient Descent vs Adam
# - Real dataset (synthetic regression)
# - Loss functions
# - Contour plots
# - Autograded exercises

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ## 📦 Dataset (Synthetic Linear Regression)

# %% [markdown]
# ## 📉 Loss Function (MSE)

# %% [markdown]
# ## ⚙️ Gradient Descent

# %% [markdown]
# ## ⚡ Adam Optimizer

# %% [markdown]
# ## 📈 Contour Plot

# %% [markdown]
# ## 🧪 Optimization Comparison

# %% [markdown]
# ## ✅ Autograded Exercise
